# %%
import requests
import json

#response1 = requests.post('https://clinicaltrialsapi.cancer.gov/v1/clinical-trials',data={"sites.org_state_or_province": ["NY"],"record_verification_date_gte": "2017-06-01","include": ["nci_id"]})
params = {'_fulltext': 'gastric'}
response2 = requests.get('https://clinicaltrialsapi.cancer.gov/v1/clinical-trials',params)
j = response2.json()
j
# Out:
# {'total': 192,
#  'trials': [{'accepts_healthy_volunteers_indicator': 'NO',
#    'acronym': None,
#    'amendment_date': '2017-08-07T00:00:00',
#    'anatomic_sites': ['Multiple'],
#    'arms': [{'arm_description': 'Patients with EGFR activating mutation receive afatinib orally (PO) once daily (QD) on days 1-28. Courses repeat every 28 days in the absence of disease progression or unacceptable toxicity.',
#      'arm_name': 'Subprotocol A (EGFR activating mutation)',
#      'arm_type': 'EXPERIMENTAL',
#      'interventions': [{'intervention_code': 'C66940',
#        'intervention_description': None,
#        'intervention_name': 'Afatinib',
#        'intervention_type': 'Drug',
#        'synonyms': ['Afatinib']},
#       {'intervention_code': 'C64263',
#        'intervention_description': None,
#        'intervention_name': 'Laboratory Biomarker Analysis',
#        'intervention_type': 'Other',
#        'synonyms': ['Laboratory Biomarker Analysis']},
# ...

# %%
import psycopg2
conn_string = "host='aact-prod.cr4nrslb1lw7.us-east-1.rds.amazonaws.com' dbname='aact' user='aact' password='aact'"
try:
    conn=psycopg2.connect(conn_string)
    print('Connected successfully.')
except:
    print ("I am unable to connect to the database.")
# Out:
# Connected successfully.
